# %% [markdown]
# <a href="https://colab.research.google.com/github/jovanailin/nordeus_data_engineering_challenge_23/blob/main/SQL_Query.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install psycopg2-binary
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 28.6 MB/s eta 0:00:00
# ...

# %%
import psycopg2

# elephantSQL details

dbname = 'tqxuhkbs'
user = 'tqxuhkbs'
password = 'yjEj8yaStN-0W2UiK-oYObVz1tAVF14e'
host = 'cornelius.db.elephantsql.com'

# %%
# create connection to postgres

pg_conn = psycopg2.connect(dbname=dbname, user=user,
                           password=password, host=host)

# %%
pg_conn.rollback()

# %%
# !pip install ipython-sql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.3 MB/s eta 0:00:00
# ...

# %%
# %load_ext sql

# Connection string in the format: postgresql://username:password@host:port/dbname
# %sql postgresql://tqxuhkbs:yjEj8yaStN-0W2UiK-oYObVz1tAVF14e@cornelius.db.elephantsql.com/tqxuhkbs

# %%
# %%sql
#
# SELECT * FROM transaction;
# Out:
#  * postgresql://tqxuhkbs:***@cornelius.db.elephantsql.com/tqxuhkbs
# 628 rows affected.
# [(47655, 1274572519, 'transaction', '81cebb24-683b-11ee-aca7-8699b86be788', 1.99, 'USD'),
#  (47610, 1274570710, 'transaction', '734ed624-683b-11ee-aca7-8699b86be788', 0.99, 'USD'),
#  (47638, 1274570626, 'transaction', '6017708e-683b-11ee-aca7-8699b86be788', 2.99, 'USD'),
#  (47530, 1274486320, 'transaction', '74b67418-683b-11ee-aca7-8699b86be788', 0.99, 'USD'),
#  (47223, 1274080210, 'transaction', '603a31fa-683b-11ee-aca7-8699b86be788', 0.99, 'EUR'),
#  (47615, 1274570697, 'transaction', '833f9b40-683b-11ee-aca7-8699b86be788', 2.99, 'EUR'),
#  (47258, 1274215002, 'transaction', '615750e0-683b-11ee-aca7-8699b86be788', 0.99, 'EUR'),
#  (47386, 1274389524, 'transaction', '6c896912-683b-11ee-aca7-8699b86be788', 2.99, 'EUR'),
#  (47226, 1274135828, 'transaction', '5ced4c8a-683b-11ee-aca7-8699b86be788', 0.99, 'EUR'),
# ...
